# %% [markdown]
# #Part 1: Setting Up

# %%
# Importing the neccessary libraries
import os
import zipfile
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import plotly.express as px
from sklearn.preprocessing import LabelEncoder

# %%
import gdown

# Downloading the Kaggle Dataset.
file_ids = ["1m99RBSAG4zIPOJ2nfRupHj-jZDteTr6G", "1p-bKN89n-r-HnDGRmVF2tDpvHA5DUv0w", "1XDBeNesyWO9YKVxh5fGtzQM4V-YXL_ZJ","1hakH4A1exZu58b8AEakkJFNktCGjMoAH","1Tf03LIjkD3GsLHO_meTUocIhdZ-uZHbM","1eInNXFn5ibTRT6R5P5ntn5jw8G-sWoPA","1YZymTI35b22W8Z_X371xAIYUWz7SztLW"]  # Add all file IDs here
destinations=["assessments.csv","courses.csv","studentAssessment.csv","studentInfo.csv","studentRegistration.csv","studentVle.csv","vle.csv"]
for i, file_id in enumerate(file_ids, 0):
    destination = f"file_{i}.csv"
    url = f"https://drive.google.com/uc?id={file_id}"
    gdown.download(url, destinations[i], quiet=False)
    print(f"Downloaded: {destinations[i]}")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1m99RBSAG4zIPOJ2nfRupHj-jZDteTr6G
# To: /content/assessments.csv
# 100%|██████████| 8.20k/8.20k [00:00<00:00, 9.90MB/s]
# Downloaded: assessments.csv
# Downloading...
# From: https://drive.google.com/uc?id=1p-bKN89n-r-HnDGRmVF2tDpvHA5DUv0w
# To: /content/courses.csv
# 100%|██████████| 526/526 [00:00<00:00, 1.42MB/s]
# Downloaded: courses.csv
# Downloading...
# From: https://drive.google.com/uc?id=1XDBeNesyWO9YKVxh5fGtzQM4V-YXL_ZJ
# To: /content/studentAssessment.csv
# 100%|██████████| 5.69M/5.69M [00:00<00:00, 23.2MB/s]
# Downloaded: studentAssessment.csv
# Downloading...
# From: https://drive.google.com/uc?id=1hakH4A1exZu58b8AEakkJFNktCGjMoAH
# To: /content/studentInfo.csv
# 100%|██████████| 3.46M/3.46M [00:00<00:00, 211MB/s]
# Downloaded: studentInfo.csv
# Downloading...
# From: https://drive.google.com/uc?id=1Tf03LIjkD3GsLHO_meTUocIhdZ-uZHbM
# To: /content/studentRegistration.csv
# 100%|██████████| 1.11M/1.11M [00:00<00:00, 104MB/s]
# Downloaded: studentRegistration.csv
# Downloading...
# From (original): https://drive.google.com/uc?id=1eInNXFn5ibTRT6R5P5ntn5jw8G-sWoPA
# From (redirected): https://drive.google.com/uc?id=1eInNXFn5ibTRT6R5P5ntn5jw8G-sWoPA&confirm=t&uuid=5e9d4304-d795-4c57-94bd-de9be5d56e9f
# To: /content/studentVle.csv
# 100%|██████████| 454M/454M [00:09<00:00, 49.3MB/s]
# Downloaded: studentVle.csv
# Downloading...
# From: https://drive.google.com/uc?id=1YZymTI35b22W8Z_X371xAIYUWz7SztLW
# To: /content/vle.csv
# 100%|██████████| 260k/260k [00:00<00:00, 69.7MB/s]
# Downloaded: vle.csv

# %%
# Define file paths
base_path = "/content/"  # Change this to your folder path
files = {
    "assessments": "assessments.csv",
    "courses": "courses.csv",
    "studentAssessment": "studentAssessment.csv",
    "studentInfo": "studentInfo.csv",
    "studentRegistration": "studentRegistration.csv",
    "studentVle": "studentVle.csv",
    "vle": "vle.csv",
}

# Load data into DataFrames
df_assessments = pd.read_csv(base_path + files["assessments"])
df_courses = pd.read_csv(base_path + files["courses"])
df_studentAssessment = pd.read_csv(base_path + files["studentAssessment"])
df_studentInfo = pd.read_csv(base_path + files["studentInfo"])
df_studentRegistration = pd.read_csv(base_path + files["studentRegistration"])
df_studentVle = pd.read_csv(base_path + files["studentVle"])
df_vle = pd.read_csv(base_path + files["vle"])

# %% [markdown]
# #Part 2: Understanding the Data

# %%
#ّFirst file
print('===='*30)
df_assessments.info()
print("-------"*30)
# Count the number of NaN values in each column
print('count the number of nan values for each column:')
print("-------"*30)
nan_count = df_assessments.isna().sum()

# Print the result
print(nan_count)
print("-------"*30)
# Out:
# ========================================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   code_module        206 non-null    object
#  1   code_presentation  206 non-null    object
#  2   id_assessment      206 non-null    int64
#  3   assessment_type    206 non-null    object
#  4   date               195 non-null    float64
#  5   weight             206 non-null    float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 9.8+ KB
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# count the number of nan values for each column:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# code_module           0
# code_presentation     0
# id_assessment         0
# assessment_type       0
# date                 11
# weight                0
# dtype: int64
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#ّSecond file
print('===='*30)
df_courses.info()
print("-------"*30)
# Count the number of NaN values in each column
print('count the number of nan values for each column:')
print("-------"*30)
nan_count = df_courses.isna().sum()

# Print the result
print(nan_count)
print("-------"*30)
# Out:
# ========================================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 3 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   code_module                 22 non-null     object
#  1   code_presentation           22 non-null     object
#  2   module_presentation_length  22 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 660.0+ bytes
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# count the number of nan values for each column:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# code_module                   0
# code_presentation             0
# module_presentation_length    0
# dtype: int64
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#ّThird file
print('===='*30)
df_studentAssessment.info()
print("-------"*30)
# Count the number of NaN values in each column
print('count the number of nan values for each column:')
print("-------"*30)
nan_count = df_studentAssessment.isna().sum()

# Print the result
print(nan_count)
print("-------"*30)
# Out:
# ========================================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173912 entries, 0 to 173911
# Data columns (total 5 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id_assessment   173912 non-null  int64
#  1   id_student      173912 non-null  int64
#  2   date_submitted  173912 non-null  int64
#  3   is_banked       173912 non-null  int64
#  4   score           173739 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 6.6 MB
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# count the number of nan values for each column:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# score             173
# dtype: int64
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# From the student Assessment dataset, there is 173 rows of scores that is blank. Meaning that 173 entries either were from students who have **FAILED** or **WITHDRAWN** from the Module.

# %%
#ّFourth file
print('===='*30)
df_studentInfo.info()
print("-------"*30)
# Count the number of NaN values in each column
print('count the number of nan values for each column:')
print("-------"*30)
nan_count = df_studentInfo.isna().sum()

# Print the result
print(nan_count)
print("-------"*30)
# Out:
# ========================================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# count the number of nan values for each column:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# code_module                0
# code_presentation          0
# id_student                 0
# gender                     0
# region                     0
# highest_education          0
# imd_band                1111
# age_band                   0
# num_of_prev_attempts       0
# studied_credits            0
# disability                 0
# final_result               0
# dtype: int64
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# From the studentInfo Dataset, it seems there is 1111 rows of imd_band missing. This could be due to the period in which the student enrolled, and it didn't input the student's imd_band.

# %%
#ّFifth file
print('===='*30)
df_studentRegistration.info()
print("-------"*30)
# Count the number of NaN values in each column
print('count the number of nan values for each column:')
print("-------"*30)
nan_count = df_studentRegistration.isna().sum()
# Print the result
print(nan_count)
print("-------"*30)
# Out:
# ========================================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   code_module          32593 non-null  object
#  1   code_presentation    32593 non-null  object
#  2   id_student           32593 non-null  int64
#  3   date_registration    32548 non-null  float64
#  4   date_unregistration  10072 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 1.2+ MB
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# count the number of nan values for each column:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# code_module                0
# code_presentation          0
# id_student                 0
# date_registration         45
# date_unregistration    22521
# dtype: int64
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# There are 45 Null entries in date_registration in the studentRegistration dataset. These means 45 students failed to register for the module on time.
#
# As for the 22521 Null entires in date_unregistration, it means that there are a total of 22521 students that did not drop out.

# %%
#ّSixth file
print('===='*30)
df_studentVle.info()
print("-------"*30)
# Count the number of NaN values in each column
print('count the number of nan values for each column:')
print("-------"*30)
nan_count = df_studentVle.isna().sum()
# Print the result
print(nan_count)
print("-------"*30)
# Out:
# ========================================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655280 entries, 0 to 10655279
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   code_module        object
#  1   code_presentation  object
#  2   id_student         int64
#  3   id_site            int64
#  4   date               int64
#  5   sum_click          int64
# dtypes: int64(4), object(2)
# memory usage: 487.8+ MB
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# count the number of nan values for each column:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# code_module          0
# code_presentation    0
# id_student           0
# id_site              0
# date                 0
# sum_click            0
# dtype: int64
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
#ّLast file
print('===='*30)
df_vle.info()
print("-------"*30)
# Count the number of NaN values in each column
print('count the number of nan values for each column:')
print("-------"*30)
nan_count = df_vle.isna().sum()
# Print the result
print(nan_count)
print("-------"*30)
# Out:
# ========================================================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6364 entries, 0 to 6363
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_site            6364 non-null   int64
#  1   code_module        6364 non-null   object
#  2   code_presentation  6364 non-null   object
#  3   activity_type      6364 non-null   object
#  4   week_from          1121 non-null   float64
#  5   week_to            1121 non-null   float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 298.4+ KB
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# count the number of nan values for each column:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# id_site                 0
# code_module             0
# code_presentation       0
# activity_type           0
# week_from            5243
# week_to              5243
# dtype: int64
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# From the VLE Dataset, the 5243 empty rows of "week_from" and "week_to" means that those rows did not specify a week the resource will be up online until.

# %%
#Specify the column of interest
column = "score"

# Drop NaN values from the 'score' column
df_studentAssessment = df_studentAssessment.dropna(subset=[column])

# Calculate statistics
mean_score = df_studentAssessment[column].mean()
median_score = df_studentAssessment[column].median()
mode_score = df_studentAssessment[column].mode().iloc[0]
#mode_score = mode_result.mode[0] if mode_result.mode.size > 0 else np.nan

# Print statistics
print(f"Mean: {mean_score}")
print(f"Median: {median_score}")
print(f"Mode: {mode_score}")

# Plot the distribution
plt.figure(figsize=(10, 6))
sns.histplot(df_studentAssessment[column], kde=True, bins=30)
plt.title(f'Distribution of {column}')
plt.xlabel(column)
plt.ylabel('Frequency')
plt.axvline(mean_score, color='r', linestyle='-', label=f'Mean: {mean_score}')
plt.axvline(median_score, color='g', linestyle='-', label=f'Median: {median_score}')
plt.axvline(mode_score, color='b', linestyle='-', label=f'Mode: {mode_score}')
plt.legend()
plt.show()
# Out:
# Mean: 75.7995729226023
# Median: 80.0
# Mode: 100.0

# %% [markdown]
# The histogram illustrates the distribution of scores in the dataset. The mean score is approximately 75.80, represented by the red dashed line, while the median score is 80.0, shown by the green dashed line. The mode of the scores is 100.0, indicated by the blue dashed line. The distribution is right-skewed, with a noticeable peak around 80 and a significant number of scores at 100. This indicates that while many students scored high, a broad range of lower scores is also present.

# %%
# Count the number of students in each module
module_counts = df_studentInfo['code_module'].value_counts()

# Calculate the percentage of students in each module
module_percentages = (module_counts / module_counts.sum()) * 100

# Create a bar plot
plt.figure(figsize=(10, 6))
bars = plt.bar(module_counts.index, module_counts, color=plt.cm.tab20.colors[:len(module_counts)])

# Add percentage labels above the bars
for bar, percentage in zip(bars, module_percentages):
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, f'{percentage:.1f}%', ha='center', va='bottom')

# Add titles and labels
plt.title('Number of Students in Each Module')
plt.xlabel('Module')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# This bar plot displays the number of students enrolled in each module, along with the percentage of the total student population represented by each module. The plot provides a clear visual comparison of student distribution across different modules. Each bar's height corresponds to the number of students, and the labels above the bars indicate the percentage of the total enrollment for each module. This helps in identifying which modules are more popular among students and can guide resource allocation and curriculum planning.

# %%
# Count the number of students in each module with each final result
module_final_result_counts = df_studentInfo.groupby(['code_module', 'final_result']).size().unstack(fill_value=0)

# Calculate the percentage of each final result within each module
module_final_result_percentages = module_final_result_counts.div(module_final_result_counts.sum(axis=1), axis=0) * 100

# Create a stacked bar plot
module_final_result_counts.plot(kind='bar', stacked=True, figsize=(12, 8), colormap='tab20')

# Add titles and labels
plt.title('Final Results of Students in Each Module')
plt.xlabel('Module')
plt.ylabel('Number of Students')
plt.legend(title='Final Result', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.show()

# %% [markdown]
# The stacked bar plot shows the distribution of final results of students across different modules. Each bar represents a module, and the segments within each bar represent the number of students achieving each final result, such as 'Pass', 'Fail', 'Withdrawn', etc. The color-coded segments allow you to compare the proportion of different final results within each module. This visualization helps identify which modules have higher or lower pass rates, as well as the prevalence of other outcomes like failures or withdrawals. This information can be valuable for understanding the performance trends in each module and identifying areas that might need improvement or further investigation.

# %%
df = df_studentInfo.groupby(['code_module', 'final_result']).agg({'id_student':'count'}).reset_index()

df['Percentage'] = df.apply(lambda x:  round(100 * (x['id_student'] / df[df['final_result'] == x['final_result']]['id_student'].sum()),2), axis=1)

fig = px.bar(df, x="final_result", y="Percentage", text="Percentage", color="code_module",
            hover_data=None, barmode = 'stack', template="seaborn")

fig.update_layout(
    margin=dict(l=20, r=50, t=50, b=20),
    title = 'Pass and Fail Percentages by Module',
    xaxis_title="Result",
    yaxis_title="Percentage [%]",
    legend_title="Code Module",
    width=700,
    height=500,
    uniformtext_minsize=9,
    uniformtext_mode='hide',
)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2b5df7b1-67b9-4a20-9b8f-cbbb3b69a3f4" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b5df7b1-67b9-4a20-9b8f-cbbb3b69a3f4")) {                    Plotly.newPlot(                        "2b5df7b1-67b9-4a20-9b8f-cbbb3b69a3f4",                        [{"alignmentgroup":"True","hovertemplate":"code_module=AAA\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"AAA","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"AAA","offsetgroup":"AAA","orientation":"v","showlegend":true,"text":[1.46,1.29,3.94,1.24],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[1.46,1.29,3.94,1.24],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"code_module=BBB\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"BBB","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""}},"name":"BBB","offsetgroup":"BBB","orientation":"v","showlegend":true,"text":[22.39,25.06,24.89,23.51],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[22.39,25.06,24.89,23.51],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"code_module=CCC\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"CCC","marker":{"color":"rgb(85,168,104)","pattern":{"shape":""}},"name":"CCC","offsetgroup":"CCC","orientation":"v","showlegend":true,"text":[16.47,11.07,9.55,19.45],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[16.47,11.07,9.55,19.45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"code_module=DDD\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DDD","marker":{"color":"rgb(196,78,82)","pattern":{"shape":""}},"name":"DDD","offsetgroup":"DDD","orientation":"v","showlegend":true,"text":[12.67,20.02,18.02,22.15],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[12.67,20.02,18.02,22.15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"code_module=EEE\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"EEE","marker":{"color":"rgb(129,114,179)","pattern":{"shape":""}},"name":"EEE","offsetgroup":"EEE","orientation":"v","showlegend":true,"text":[11.77,7.97,10.47,7.11],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[11.77,7.97,10.47,7.11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"code_module=FFF\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"FFF","marker":{"color":"rgb(147,120,96)","pattern":{"shape":""}},"name":"FFF","offsetgroup":"FFF","orientation":"v","showlegend":true,"text":[22.16,24.26,24.09,23.66],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[22.16,24.26,24.09,23.66],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"code_module=GGG\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"GGG","marker":{"color":"rgb(218,139,195)","pattern":{"shape":""}},"name":"GGG","offsetgroup":"GGG","orientation":"v","showlegend":true,"text":[13.1,10.32,9.04,2.88],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[13.1,10.32,9.04,2.88],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234, ...

# %%
# Filter the DataFrame to include only rows where 'code_module' is 'BBB'
df_studentInfo_FFF = df_studentInfo[df_studentInfo['code_module'] == 'FFF'].copy()

# Verify by displaying the info
df_studentInfo_FFF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7762 entries, 22297 to 30058
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           7762 non-null   object
#  1   code_presentation     7762 non-null   object
#  2   id_student            7762 non-null   int64
#  3   gender                7762 non-null   object
#  4   region                7762 non-null   object
#  5   highest_education     7762 non-null   object
#  6   imd_band              7395 non-null   object
#  7   age_band              7762 non-null   object
#  8   num_of_prev_attempts  7762 non-null   int64
#  9   studied_credits       7762 non-null   int64
#  10  disability            7762 non-null   object
#  11  final_result          7762 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 788.3+ KB

# %%
# Calculate gender distribution
genero = df_studentInfo_FFF[['id_student', 'gender']].drop_duplicates().groupby('gender').agg({'id_student':'count'}).reset_index()

# Calculate percentage
genero['Percentage'] = genero.apply(lambda x: round(100 * (x['id_student'] / genero['id_student'].sum()), 2), axis=1)

# Create bar plot
fig = px.bar(genero, x='gender', y='id_student',
              text='id_student', color='gender', hover_data=['id_student'],
              template="seaborn")

# Update layout
fig.update_layout(
    margin=dict(l=20, r=50, t=50, b=20),
    title='Distribution Of Gender for Course FFF',
    xaxis_title="Gender",
    yaxis_title="Number Of Students",
    legend_title="Gender",
    width=600,
    height=400,
    uniformtext_minsize=10,
    uniformtext_mode='hide',
)

# Show plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="77f6ef50-b488-4b00-b9f1-9584ef60e374" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77f6ef50-b488-4b00-b9f1-9584ef60e374")) {                    Plotly.newPlot(                        "77f6ef50-b488-4b00-b9f1-9584ef60e374",                        [{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003eid_student=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"text":[1350.0],"textposition":"auto","x":["F"],"xaxis":"x","y":[1350],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=%{x}\u003cbr\u003eid_student=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"text":[6047.0],"textposition":"auto","x":["M"],"xaxis":"x","y":[6047],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274 ...

# %%
df = df_studentInfo_FFF.groupby(['gender', 'final_result']).agg({'id_student':'count'}).reset_index()

df['Percentage'] = df.apply(lambda x:  round(100 * (x['id_student'] / df[df['final_result'] == x['final_result']]['id_student'].sum()),2), axis=1)

fig = px.bar(df, x="final_result", y="Percentage", text="Percentage", color="gender",
            hover_data=['Percentage'], barmode = 'stack', template="seaborn")

fig.update_layout(
    margin=dict(l=20, r=50, t=50, b=20),
    title = 'Final Result By Gender (FFF)',
    xaxis_title="Final Result",
    yaxis_title="Percentage [%]",
    legend_title="Gender",
    width=600,
    height=400,
    uniformtext_minsize=10,
    uniformtext_mode='hide',
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="44f6b3c3-ed17-4d4c-bbe7-8bd2383464f4" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44f6b3c3-ed17-4d4c-bbe7-8bd2383464f4")) {                    Plotly.newPlot(                        "44f6b3c3-ed17-4d4c-bbe7-8bd2383464f4",                        [{"alignmentgroup":"True","hovertemplate":"gender=F\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"text":[22.09,14.73,18.13,19.73],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[22.09,14.73,18.13,19.73],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=M\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"text":[77.91,85.27,81.87,80.27],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[77.91,85.27,81.87,80.27],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1. ...

# %%
df = df_studentInfo_FFF.groupby(['region', 'final_result']).agg({'id_student':'count'}).reset_index()

df['Percentage'] = df.apply(lambda x:  round(100 * (x['id_student'] / df[df['final_result'] == x['final_result']]['id_student'].sum()),2), axis=1)

fig = px.bar(df, x="final_result", y="Percentage", text="Percentage", color="region",
            hover_data=['Percentage'], barmode = 'stack', template='seaborn')

fig.update_layout(
    margin=dict(l=20, r=50, t=50, b=20),
    title = 'Final Result By Region (FFF)',
    xaxis_title="Result",
    yaxis_title="Percentage [%]",
    legend_title="Region",
    width=800,
    height=700,
    uniformtext_minsize=9,
    uniformtext_mode='hide',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="18326b8a-6c96-4d74-b3f7-fd66b8894abe" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("18326b8a-6c96-4d74-b3f7-fd66b8894abe")) {                    Plotly.newPlot(                        "18326b8a-6c96-4d74-b3f7-fd66b8894abe",                        [{"alignmentgroup":"True","hovertemplate":"region=East Anglian Region\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Anglian Region","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"East Anglian Region","offsetgroup":"East Anglian Region","orientation":"v","showlegend":true,"text":[10.15,8.18,9.57,9.57],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[10.15,8.18,9.57,9.57],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=East Midlands Region\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"East Midlands Region","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""}},"name":"East Midlands Region","offsetgroup":"East Midlands Region","orientation":"v","showlegend":true,"text":[6.57,6.95,7.29,8.36],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[6.57,6.95,7.29,8.36],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Ireland\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Ireland","marker":{"color":"rgb(85,168,104)","pattern":{"shape":""}},"name":"Ireland","offsetgroup":"Ireland","orientation":"v","showlegend":true,"text":[4.78,5.26,5.24,2.7],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[4.78,5.26,5.24,2.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=London Region\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"London Region","marker":{"color":"rgb(196,78,82)","pattern":{"shape":""}},"name":"London Region","offsetgroup":"London Region","orientation":"v","showlegend":true,"text":[8.96,11.75,9.94,12.94],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[8.96,11.75,9.94,12.94],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=North Region\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North Region","marker":{"color":"rgb(129,114,179)","pattern":{"shape":""}},"name":"North Region","offsetgroup":"North Region","orientation":"v","showlegend":true,"text":[8.51,5.44,7.76,6.08],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[8.51,5.44,7.76,6.08],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=North Western Region\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"North Western Region","marker":{"color":"rgb(147,120,96)","pattern":{"shape":""}},"name":"North Western Region","offsetgroup":"North Western Region","orientation":"v","showlegend":true,"text":[8.06,10.23,8.56,9.74],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[8.06,10.23,8.56,9.74],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"region=Scotland\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Scotland","marker":{"color":"rgb(218,139,195)","pattern":{"shape":""}},"name":"Scotland","offsetgroup":"Scotland","orientation":"v","showlegend":true,"text":[ ...

# %% [markdown]
# The chart compares the percentage of final results across ten different regions. Each region’s bar is divided into three sections representing different outcomes: Fail, Pass, and Distinction. Here are the key observations:
#
# * East Midlands Region: Approximately 10% of students in this region received a Fail grade, 60% passed, and 30% achieved Distinction.
# * London Region: London had 5.47% Fail, 6.37% Pass, and 5.46% Distinction.
# * North Region: This area had 8.79% Fail, 7.57% Pass, and 7.68% Distinction.
# * Scotland: Scotland’s performance was 6.19% Fail, 7.46% Pass, and 7.12% Distinction.
# * South East Region: Students here achieved 5.16% Fail, 5.39% Pass, and 5.61% Distinction.
# * South West Region: The percentages were 5.66% Fail, 5.85% Pass, and 5.59% Distinction.
# * Yorkshire Region: Yorkshire had 6.53% Fail, 6.55% Pass, and 6.55% Distinction.
#
# This visualization provides an easy comparison of performance outcomes across regions.

# %%
df = df_studentInfo_FFF.groupby(['highest_education', 'final_result']).agg({'id_student':'count'}).reset_index()

df['Percentage'] = df.apply(lambda x:  round(100 * (x['id_student'] / df[df['final_result'] == x['final_result']]['id_student'].sum()),2), axis=1)

fig = px.bar(df, x="final_result", y="Percentage", text='Percentage', color="highest_education",
            hover_data=['Percentage'], barmode = 'stack', template='seaborn')

fig.update_layout(
    margin=dict(l=20, r=50, t=50, b=20),
    title = 'Final Result By Highest Education (FFF)',
    xaxis_title="Final Result",
    yaxis_title="Quantidade [Alunos]",
    legend_title="Highest Education",
    width=800,
    height=700,
    uniformtext_minsize=8,
    uniformtext_mode='hide',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4be1c59e-4dd1-4011-9e29-e5f280f5f5f0" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4be1c59e-4dd1-4011-9e29-e5f280f5f5f0")) {                    Plotly.newPlot(                        "4be1c59e-4dd1-4011-9e29-e5f280f5f5f0",                        [{"alignmentgroup":"True","hovertemplate":"highest_education=A Level or Equivalent\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"A Level or Equivalent","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"A Level or Equivalent","offsetgroup":"A Level or Equivalent","orientation":"v","showlegend":true,"text":[53.28,38.87,46.71,37.54],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[53.28,38.87,46.71,37.54],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"highest_education=HE Qualification\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HE Qualification","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""}},"name":"HE Qualification","offsetgroup":"HE Qualification","orientation":"v","showlegend":true,"text":[20.0,10.52,15.92,10.15],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[20.0,10.52,15.92,10.15],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"highest_education=Lower Than A Level\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Lower Than A Level","marker":{"color":"rgb(85,168,104)","pattern":{"shape":""}},"name":"Lower Than A Level","offsetgroup":"Lower Than A Level","orientation":"v","showlegend":true,"text":[24.33,48.45,35.86,50.4],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[24.33,48.45,35.86,50.4],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"highest_education=No Formal quals\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No Formal quals","marker":{"color":"rgb(196,78,82)","pattern":{"shape":""}},"name":"No Formal quals","offsetgroup":"No Formal quals","orientation":"v","showlegend":true,"text":[0.6,1.46,0.67,1.33],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[0.6,1.46,0.67,1.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"highest_education=Post Graduate Qualification\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Post Graduate Qualification","marker":{"color":"rgb(129,114,179)","pattern":{"shape":""}},"name":"Post Graduate Qualification","offsetgroup":"Post Graduate Qualification","orientation":"v","showlegend":true,"text":[1.79,0.7,0.84,0.58],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[1.79,0.7,0.84,0.58],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"typ ...

# %%
df = df_studentInfo_FFF.groupby(['age_band', 'final_result']).agg({'id_student':'count'}).reset_index()

df['Percentage'] = df.apply(lambda x:  round(100 * (x['id_student'] / df[df['final_result'] ==\
     x['final_result']]['id_student'].sum()),2), axis=1)

fig = px.bar(df, x="final_result", y="Percentage", text="Percentage", color="age_band",
            hover_data=['Percentage'], barmode = 'stack', template='seaborn')

fig.update_layout(
    margin=dict(l=20, r=50, t=50, b=20),
    title = 'Final Result By Age (FFF)',
    xaxis_title="Final Result",
    yaxis_title="Percentage [%]",
    legend_title="Age",
    width=800,
    height=700,
    uniformtext_minsize=9,
    uniformtext_mode='hide',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e6a31723-81ec-40a2-ba5f-7c584e962f6a" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6a31723-81ec-40a2-ba5f-7c584e962f6a")) {                    Plotly.newPlot(                        "e6a31723-81ec-40a2-ba5f-7c584e962f6a",                        [{"alignmentgroup":"True","hovertemplate":"age_band=0-35\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0-35","marker":{"color":"rgb(76,114,176)","pattern":{"shape":""}},"name":"0-35","offsetgroup":"0-35","orientation":"v","showlegend":true,"text":[65.67,77.79,73.34,74.49],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[65.67,77.79,73.34,74.49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"age_band=35-55\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"35-55","marker":{"color":"rgb(221,132,82)","pattern":{"shape":""}},"name":"35-55","offsetgroup":"35-55","orientation":"v","showlegend":true,"text":[33.88,21.8,26.19,25.34],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[33.88,21.8,26.19,25.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"age_band=55\u003c=\u003cbr\u003efinal_result=%{x}\u003cbr\u003ePercentage=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"55\u003c=","marker":{"color":"rgb(85,168,104)","pattern":{"shape":""}},"name":"55\u003c=","offsetgroup":"55\u003c=","orientation":"v","showlegend":true,"text":[0.45,0.41,0.47,0.17],"textposition":"auto","x":["Distinction","Fail","Pass","Withdrawn"],"xaxis":"x","y":[0.45,0.41,0.47,0.17],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"rgb(36,36,36)"},"error_y":{"color":"rgb(36,36,36)"},"marker":{"line":{"color":"rgb(234,234,242)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"baxis":{"endlinecolor":"rgb(36,36,36)","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"rgb(36,36,36)"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137,"rgb(47,23,57)"],[0.18823529411764706,"rgb(71,28,72)"],[0.25098039215686274,"rgb(97,30,82)"],[0.3137254901960784,"rgb(123,30,89)"],[0.3764705882352941,"rgb(150,27,91)"],[0.4392156862745098,"rgb(177,22,88)"],[0.5019607843137255,"rgb(203,26,79)"],[0.5647058823529412,"rgb(223,47,67)"],[0.6274509803921569,"rgb(236,76,61)"],[0.6901960784313725,"rgb(242,107,73)"],[0.7529411764705882,"rgb(244,135,95)"],[0.8156862745098039,"rgb(245,162,122)"],[0.8784313725490196,"rgb(246,188,153)"],[0.9411764705882353,"rgb(247,212,187)"],[1.0,"rgb(250,234,220)"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"tickcolor":"rgb(36,36,36)","ticklen":8,"ticks":"outside","tickwidth":2},"colorscale":[[0.0,"rgb(2,4,25)"],[0.06274509803921569,"rgb(24,15,41)"],[0.12549019607843137 ...

# %%
df_studentInfo_FFF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7762 entries, 22297 to 30058
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           7762 non-null   object
#  1   code_presentation     7762 non-null   object
#  2   id_student            7762 non-null   int64
#  3   gender                7762 non-null   object
#  4   region                7762 non-null   object
#  5   highest_education     7762 non-null   object
#  6   imd_band              7395 non-null   object
#  7   age_band              7762 non-null   object
#  8   num_of_prev_attempts  7762 non-null   int64
#  9   studied_credits       7762 non-null   int64
#  10  disability            7762 non-null   object
#  11  final_result          7762 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 788.3+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Select only the relevant columns (excluding id_student)
df_selected = df_studentInfo_FFF[['disability','imd_band','gender','code_presentation','highest_education','age_band','region','final_result', 'num_of_prev_attempts', 'studied_credits']]

# First, encode categorical columns
df_encoded = pd.get_dummies(df_selected)

# Calculate the correlation matrix for all columns
correlation_matrix = df_encoded.corr()

# Plot the heatmap
plt.figure(figsize=(80, 80))

sns.heatmap(correlation_matrix,
            annot=True,
            cmap='coolwarm',
            linewidths=0.5,
            annot_kws={"size": 24},
            fmt=".2f")

plt.xticks(fontsize=14, rotation=90)
plt.yticks(fontsize=14, rotation=0)
plt.show()
